# %%
# Install OpenNMT-py 3.x
# !pip3 install OpenNMT-py
# Out:
# Requirement already satisfied: OpenNMT-py in /venv/main/lib/python3.10/site-packages (3.5.1)
# Requirement already satisfied: six in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (1.17.0)
# Requirement already satisfied: pyahocorasick in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (2.1.0)
# Requirement already satisfied: spacy in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (3.8.4)
# Requirement already satisfied: pyonmttok<2,>=1.37 in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (1.37.1)
# Requirement already satisfied: waitress in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (3.0.2)
# Requirement already satisfied: fasttext-wheel in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (0.9.2)
# Requirement already satisfied: configargparse in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (1.7)
# Requirement already satisfied: flask in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (3.1.0)
# Requirement already satisfied: sacrebleu in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (2.5.1)
# Requirement already satisfied: rapidfuzz in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (3.12.2)
# Requirement already satisfied: pyyaml in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (6.0.2)
# Requirement already satisfied: ctranslate2<5,>=4 in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (4.5.0)
# Requirement already satisfied: torch<2.3,>=2.1 in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (2.2.2)
# Requirement already satisfied: tensorboard>=2.3 in /venv/main/lib/python3.10/site-packages (from OpenNMT-py) (2.19.0)
# Requirement already satisfied: numpy in /venv/main/lib/python3.10/site-packages (from ctranslate2<5,>=4->OpenNMT-py) (2.1.2)
# Requirement already satisfied: setuptools in /venv/main/lib/python3.10/site-packages (from ctranslate2<5,>=4->OpenNMT-py) (59.6.0)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (24.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (3.7)
# Requirement already satisfied: absl-py>=0.4 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (2.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (0.7.2)
# Requirement already satisfied: grpcio>=1.48.2 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (1.71.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /venv/main/lib/python3.10/site-packages (from tensorboard>=2.3->OpenNMT-py) (6.30.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (11.0.2.54)
# Requirement already satisfied: networkx in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.0.106)
# Requirement already satisfied: typing-extensions>=4.8.0 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (4.12.2)
# Requirement already satisfied: sympy in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (1.13.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (11.4.5.107)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (2.19.3)
# Requirement already satisfied: filelock in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.17.0)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.1.4)
# Requirement already satisfied: fsspec in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (2025.3.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /venv/main/lib/python3.10/site-packages (from torch<2.3,>=2.1->OpenNMT-py) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /venv/main/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3,>=2.1->OpenNMT-py) (12.4.127)
# Requirement already satisfied: pybind11>=2.2 in /venv/main/lib/python3.10/site-packages (from fasttext-wheel->OpenNMT-py) (2.13.6)
# Requirement already satisfied: itsdangerous>=2.2 in /venv/main/lib/python3.10/site-packages (from flask->OpenNMT-py) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /venv/main/lib/python3.10/site-packages (from flask->OpenNMT-py) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /venv/main/lib/python3.10/site-packages (from flask->OpenNMT-py) (8.1.8)
# Requirement already satisfied: colorama in /venv/main/lib/python3.10/site-packages (from sacrebleu->OpenNMT-py) (0.4.6)
# Requirement already satisfied: tabulate>=0.8.9 in /venv/main/lib/python3.10/site-packages (from sacrebleu->OpenNMT-py) (0.9.0)
# Requirement already satisfied: lxml in /venv/main/lib/python3.10/site-packages (from sacrebleu->OpenNMT-py) (5.3.1)
# Requirement already satisfied: portalocker in /venv/main/lib/python3.10/site-packages (from sacrebleu->OpenNMT-py) (3.1.1)
# Requirement already satisfied: regex in /venv/main/lib/python3.10/site-packages (from sacrebleu->OpenNMT-py) (2024.11.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (2.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (2.10.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (4.67.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (2.0.11)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (8.3.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (3.0.9)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (2.5.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (3.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (1.0.5)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (0.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (2.32.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /venv/main/lib/python3.10/site-packages (from spacy->OpenNMT-py) (1.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.10/site-packages (from jinja2->torch<2.3,>=2.1->OpenNMT-py) (2.1.5)
# Requirement already satisfied: language-data>=1.2 in /venv/main/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->OpenNMT-py) (1.3.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /venv/main/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->OpenNMT-py) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /venv/main/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->OpenNMT-py) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy->OpenNMT-py) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy->OpenNMT-py) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy->OpenNMT-py) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy->OpenNMT-py) (3.10)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /venv/main/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy->OpenNMT-py) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /venv/main/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy->OpenNMT-py) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /venv/main/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy->OpenNMT-py) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /venv/main/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy->OpenNMT-py) (1.5.4)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /venv/main/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy->OpenNMT-py) (7.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /venv/main/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy->OpenNMT-py) (0.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy->torch<2.3,>=2.1->OpenNMT-py) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /venv/main/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->OpenNMT-py) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /venv/main/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->OpenNMT-py) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /venv/main/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->OpenNMT-py) (2.19.1)
# Requirement already satisfied: wrapt in /venv/main/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->OpenNMT-py) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /venv/main/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->OpenNMT-py) (0.1.2)

# %%
# Create the YAML configuration file
# On a regular machine, you can create it manually or with nano
# Note here we are using some smaller values because the dataset is small
# For larger datasets, consider increasing: train_steps, valid_steps, warmup_steps, save_checkpoint_steps, keep_checkpoint

config = '''# config.yaml


## Where the samples will be written
save_data: run

# Training files
data:
    corpus_1:
        path_src: en-zh.en-filtered.en.subword.train
        path_tgt: en-zh.zh-filtered.zh.subword.train
        transforms: [filtertoolong]
    valid:
        path_src: en-zh.en-filtered.en.subword.dev
        path_tgt: en-zh.zh-filtered.zh.subword.dev
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: run/source.vocab
tgt_vocab: run/target.vocab

# Vocabulary size - should be the same as in sentence piece
src_vocab_size: 50000
tgt_vocab_size: 50000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: source.model
tgt_subword_model: target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: models/model.fren

# Stop training if it does not imporve after n validations
early_stopping: 4

# Default: 5000 - Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
# keep_checkpoint: 3

seed: 3435

# Default: 100000 - Train the model to max n steps 
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 3000

# Default: 10000 - Run validation after n steps
valid_steps: 1000

# Default: 4000 - for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 4096
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %%
# Find the number of CPUs/cores on the machine
# !nproc --all

# %%
# Build Vocabulary

# -config: path to your config.yaml file
# -n_sample: use -1 to build vocabulary on all the segment in the training dataset
# -num_threads: change it to match the number of CPUs to run it faster

# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 7
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-21 01:38:12,956 INFO] Counter vocab from -1 samples.
# [2025-03-21 01:38:12,956 INFO] n_sample=-1: Build vocab on full datasets.
# [2025-03-21 01:38:16,602 INFO] Counters src: 4594
# [2025-03-21 01:38:16,602 INFO] Counters tgt: 2820

# %%
# Check if the GPU is active
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-3da117a9-dc75-64e3-3c01-4f5d3b83c278)

# %%
# Check if the GPU is visable to PyTorch
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# NVIDIA A100-SXM4-40GB
# Free GPU memory: 39900.25 out of: 40326.375

# %%
# Train the NMT model
# !onmt_train -config config.yaml
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/venv/main/bin/onmt_train", line 5, in <module>
#     from onmt.bin.train import main
#   File "/venv/main/lib/python3.10/site-packages/onmt/__init__.py", line 2, in <module>
#     import onmt.inputters
#   File "/venv/main/lib/python3.10/site-packages/onmt/inputters/__init__.py", line 7, in <module>
#     from onmt.inputters.text_utils import text_sort_key, process, numericalize, tensorify
#   File "/venv/main/lib/python3.10/site-packages/onmt/inputters/text_utils.py", line 1, in <module>
#     import torch
#   File "/venv/main/lib/python3.10/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/venv/main/lib/python3.10/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/venv/main/lib/python3.10/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/venv/main/lib/python3.10/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/venv/main/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /venv/main/lib/python3.10/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# [2025-03-20 18:14:31,433 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-20 18:14:31,433 INFO] Parsed 2 corpora from -data.
# [2025-03-20 18:14:31,433 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2025-03-20 18:14:31,447 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', '▁', '。', ',', ':', '?', '.']
# [2025-03-20 18:14:31,447 INFO] The decoder start token is: <s>
# [2025-03-20 18:14:31,447 INFO] Building model...
# [2025-03-20 18:14:32,249 INFO] Switching model to float32 for amp/apex_amp
# [2025-03-20 18:14:32,250 INFO] Non quantized layer compute is fp16
# [2025-03-20 18:14:32,631 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(4600, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(2824, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0-5): 6 x TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=2824, bias=True)
# )
# [2025-03-20 18:14:32,634 INFO] encoder: 21242880
# [2025-03-20 18:14:32,635 INFO] decoder: 28079880
# [2025-03-20 18:14:32,635 INFO] * number of parameters: 49322760
# [2025-03-20 18:14:32,635 INFO] Trainable parameters = {'torch.float32': 49322760, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2025-03-20 18:14:32,635 INFO] Non trainable parameters = {'torch.float32': 0, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2025-03-20 18:14:32,636 INFO]  * src vocab size = 4600
# [2025-03-20 18:14:32,636 INFO]  * tgt vocab size = 2824
# [2025-03-20 18:14:32,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2025-03-20 18:14:32,928 INFO] Starting training on GPU: [0]
# [2025-03-20 18:14:32,928 INFO] Start training loop and validate every 1000 steps...
# [2025-03-20 18:14:32,928 INFO] Scoring with: ['filtertoolong']
# [2025-03-20 18:14:33,059 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2025-03-20 18:14:34,491 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:34,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2025-03-20 18:14:34,530 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2025-03-20 18:14:35,405 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:35,406 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2025-03-20 18:14:36,385 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:36,386 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2025-03-20 18:14:36,423 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# [2025-03-20 18:14:37,480 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:37,480 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# [2025-03-20 18:14:38,467 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=7)
#
# [2025-03-20 18:14:38,467 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# [2025-03-20 18:14:38,503 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# [2025-03-20 18:14:39,390 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:39,390 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# [2025-03-20 18:14:40,380 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:40,381 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# [2025-03-20 18:14:40,418 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# [2025-03-20 18:14:41,478 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:41,478 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# [2025-03-20 18:14:42,363 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=6)
#
# [2025-03-20 18:14:42,363 INFO] Weighted corpora loaded so far:
# 			* corpus_1:
INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1407
# [2025-03-20 18:30:01,253 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=7)
#
# [2025-03-20 18:30:01,254 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1408
# [2025-03-20 18:30:01,569 INFO] Step 3000/ 3000; acc: 99.8; ppl:   3.1; xent: 1.1; lr: 0.00161; sents:   84474; bsz: 1572/1729/211; 20384/22417 tok/s;    929 sec;
# [2025-03-20 18:30:01,645 INFO] valid stats calculation
#                            took: 0.07422780990600586 s.
# [2025-03-20 18:30:01,646 INFO] Train perplexity: 4.09312
# [2025-03-20 18:30:01,646 INFO] Train accuracy: 95.4841
# [2025-03-20 18:30:01,646 INFO] Sentences processed: 2.52498e+06
# [2025-03-20 18:30:01,646 INFO] Average bsz: 1578/1731/210
# [2025-03-20 18:30:01,646 INFO] Validation perplexity: 299.476
# [2025-03-20 18:30:01,646 INFO] Validation accuracy: 35.8885
# [2025-03-20 18:30:01,646 INFO] Decreasing patience: 3/4
# [2025-03-20 18:30:01,649 INFO] Saving checkpoint models/model.fren_step_3000.pt

# %% [markdown]
# ## Translate

# %%
# Translate the "subworded" source file of the test dataset
# Change the model name, if needed.
# !onmt_translate -model models/model.fren_step_3000.pt -src en-zh.zh-filtered.zh.subword.test -output en.translated -gpu 0 -min_length 1
# Out:
# [2025-03-20 18:38:03,064 INFO] Loading checkpoint from models/model.fren_step_3000.pt
# [2025-03-20 18:38:03,915 INFO] Loading data into the model
# [2025-03-20 18:38:05,816 INFO] PRED SCORE: -0.3778, PRED PPL: 1.46 NB SENTENCES: 200
# Time w/o python interpreter load/terminate:  2.7549333572387695

# %%
# %pip install "numpy<2"
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 92.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# Check the first 5 lines of the translation file
# !head -n 30 en.translated
# Out:
# ▁Of ▁course .
# ▁And ▁Le gad ema ?
# ▁Perfect .
# ▁V olunteer : ▁Yes .
# ▁Electr i C ity .
# ▁Where ▁is ▁Olu ▁from ?
# ▁A llow ▁your ▁eyes ▁to ▁close , ▁on ▁five , ▁four , ▁three , ▁two , ▁one .
# ▁Hope ful ly ▁everybody .
# ▁There ' s ▁no ▁question .
# ▁A udience : ▁Now .
# ▁A udience : ▁ 6 .
# ▁Be ▁gen u ine .
# ▁What ▁happens ?
# ▁Woo ▁hoo !
# ▁So , ▁lin ked ▁data ▁-- ▁it ' s ▁hu
# ▁BJ : ▁Ab out ▁ 4 0 ▁people .
# ▁And ▁even tually , ▁we ▁found ▁our ▁photo bomb ing ▁Ka up ich phys ▁e el
# ▁False .
# ▁They ▁are ▁elephant - adapt ed .
# ▁That ' s ▁all .
# ▁L isten .
# ▁It ' s ▁remarkable .
# ▁There . ▁Good .
# ▁June ▁Co hen : ▁So ▁I s abel ▁ — ▁I A : ▁Thank ▁you .
# ▁You ' re ▁V - I - O - L - E - N - T .
# ▁We ▁sh all .
# ▁And ▁here ' s ▁the ▁ rub .
# ▁One , ▁two , ▁three , ▁four ,
# ▁Well , ▁p retty ▁ba d .
# ▁Hi ▁there .

# %%
# If needed install/update sentencepiece
# !pip3 install --upgrade -q sentencepiece

# Desubword the translation file
# !python3 ./MT-Preparation/subwording/3-desubword.py ./target.model en.translated
# Out:
# Done desubwording! Output: en.translated.desubword

# %%
# Desubword the target file (reference) of the test dataset
# Note: You might as well have split files *before* subwording during dataset preperation, 
# but sometimes datasets have tokeniztion issues, so this way you are sure the file is really untokenized.
# !python3 ./MT-Preparation/subwording/3-desubword.py ./target.model en-zh.en-filtered.en.subword.test
# Out:
# Done desubwording! Output: en-zh.en-filtered.en.subword.test.desubword

# %%
# Check the first 5 lines of the desubworded translation file
# !head -n 30 en.translated.desubword

print("---------------")
# Check the first 5 lines of the desubworded reference
# !head -n 30 en-zh.en-filtered.en.subword.test.desubword
# Out:
# Of course.
# And Legadema?
# Perfect.
# Volunteer: Yes.
# ElectriCity.
# Where is Olu from?
# Allow your eyes to close, on five, four, three, two, one.
# Hopefully everybody.
# There's no question.
# Audience: Now.
# Audience: 6.
# Be genuine.
# What happens?
# Woo hoo!
# So, linked data -- it's hu
# BJ: About 40 people.
# And eventually, we found our photobombing Kaupichphys eel
# False.
# They are elephant-adapted.
# That's all.
# Listen.
# It's remarkable.
# There. Good.
# June Cohen: So Isabel — IA: Thank you.
# You're V-I-O-L-E-N-T.
# We shall.
# And here's the rub.
# One, two, three, four,
# Well, pretty bad.
# Hi there.
# ---------------
# Sign language.
# Does it say "Michelle Obama" under the picture?
# That's you.
# Volunteer: No.
# Telegraph? No.
# I don't care. It's a loaner.
# Okay, so computer translation, not yet good enough.
# You've got Lady Gaga.
# Rives: Exactly.
# It's a remarkable thing.
# 65 dollars.
# Sincerely, Mr Micheal Bangura.
# What happened?
# Yeah, yeah!
# obese ...
# BJ: Joey.
# There's magic to love!
# False.
# Like a man.
# Oh, it's so sad.
# Continue, teacher.
# Yeah. So, good.
# Okay?
# IA: Aww, thank you. JC: Hands down. IA: No, it's makeup.
# That's Peter? MS: All right.
# We adapt.
# Not silicon.
# February.
# You're doing worse." Frown.
# Hi, everybody.

# %% [markdown]
# ## Evaluation

# %%
# Download the BLEU script
# !wget https://raw.githubusercontent.com/ymoslem/MT-Evaluation/main/BLEU/compute-bleu.py
# Out:
# --2025-03-20 18:42:23--  https://raw.githubusercontent.com/ymoslem/MT-Evaluation/main/BLEU/compute-bleu.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 957 [text/plain]
# Saving to: ‘compute-bleu.py’
#
# compute-bleu.py     100%[===================>]     957  --.-KB/s    in 0s
#
# 2025-03-20 18:42:23 (46.4 MB/s) - ‘compute-bleu.py’ saved [957/957]

# %%
# Install sacrebleu
# !pip3 install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in /venv/main/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: regex in /venv/main/lib/python3.10/site-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: portalocker in /venv/main/lib/python3.10/site-packages (from sacrebleu) (3.1.1)
# Requirement already satisfied: numpy>=1.17 in /venv/main/lib/python3.10/site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: tabulate>=0.8.9 in /venv/main/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: lxml in /venv/main/lib/python3.10/site-packages (from sacrebleu) (5.3.1)
# Requirement already satisfied: colorama in /venv/main/lib/python3.10/site-packages (from sacrebleu) (0.4.6)

# %%
# Evaluate the translation (without subwording)
# !python3 compute-bleu.py en-zh.en-filtered.en.subword.test.desubword en.translated.desubword
# Out:
# Reference 1st sentence: Sign language.
# MTed 1st sentence: Of course.
# BLEU:  7.0510299934554235
