# %%
# Install OpenNMT-py 3.x
# !pip3 install OpenNMT-py

# %%
# Create the YAML configuration file
# On a regular machine, you can create it manually or with nano
# Note here we are using some smaller values because the dataset is small
# For larger datasets, consider increasing: train_steps, valid_steps, warmup_steps, save_checkpoint_steps, keep_checkpoint

config = '''# config.yaml


## Where the samples will be written
save_data: run

# Training files
data:
    corpus_1:
        path_src: en-zh.zh-filtered.zh.subword.train
        path_tgt: en-zh.en-filtered.en.subword.train
        transforms: [filtertoolong]
    valid:
        path_src: en-zh.zh-filtered.zh.subword.dev
        path_tgt: en-zh.en-filtered.en.subword.dev
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: run/source.vocab
tgt_vocab: run/target.vocab

# Vocabulary size - should be the same as in sentence piece
src_vocab_size: 10000
tgt_vocab_size: 10000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: source.model
tgt_subword_model: target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: models/model.fren

# Stop training if it does not imporve after n validations
early_stopping: 4

# Default: 5000 - Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
# keep_checkpoint: 3

seed: 3435

# Default: 100000 - Train the model to max n steps 
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 3000

# Default: 10000 - Run validation after n steps
valid_steps: 1000

# Default: 4000 - for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
#gpu_ranks: [1]

# Batching
bucket_size: 262144
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %%
# Find the number of CPUs/cores on the machine
# !nproc --all

# %%
# Build Vocabulary

# -config: path to your config.yaml file
# -n_sample: use -1 to build vocabulary on all the segment in the training dataset
# -num_threads: change it to match the number of CPUs to run it faster

# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 7
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-21 01:38:12,956 INFO] Counter vocab from -1 samples.
# [2025-03-21 01:38:12,956 INFO] n_sample=-1: Build vocab on full datasets.
# [2025-03-21 01:38:16,602 INFO] Counters src: 4594
# [2025-03-21 01:38:16,602 INFO] Counters tgt: 2820

# %%
# Check if the GPU is active
# !nvidia-smi -L

# %%
# Check if the GPU is visable to PyTorch
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)

# %%
# Train the NMT model
# !onmt_train -config config.yaml
# Out:
# [2025-03-21 01:39:11,476 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2025-03-21 01:39:11,476 INFO] Parsed 2 corpora from -data.
# [2025-03-21 01:39:11,476 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2025-03-21 01:39:11,486 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', '▁', '。', ',', ':', '?', '.']
# [2025-03-21 01:39:11,487 INFO] The decoder start token is: <s>
# [2025-03-21 01:39:11,487 INFO] Building model...
# [2025-03-21 01:39:12,872 INFO] Switching model to float32 for amp/apex_amp
# [2025-03-21 01:39:12,872 INFO] Non quantized layer compute is fp16
# [2025-03-21 01:39:12,875 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(4600, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(2824, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0-5): 6 x TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=2824, bias=True)
# )
# [2025-03-21 01:39:12,878 INFO] encoder: 21242880
# [2025-03-21 01:39:12,878 INFO] decoder: 28079880
# [2025-03-21 01:39:12,878 INFO] * number of parameters: 49322760
# [2025-03-21 01:39:12,878 INFO] Trainable parameters = {'torch.float32': 49322760, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2025-03-21 01:39:12,879 INFO] Non trainable parameters = {'torch.float32': 0, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2025-03-21 01:39:12,879 INFO]  * src vocab size = 4600
# [2025-03-21 01:39:12,879 INFO]  * tgt vocab size = 2824
# /Users/jcjustin/opt/anaconda3/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:126: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# [2025-03-21 01:39:13,319 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2025-03-21 01:39:13,319 INFO] Starting training on CPU, could be very slow
# [2025-03-21 01:39:13,319 INFO] Start training loop and validate every 1000 steps...
# [2025-03-21 01:39:13,319 INFO] Scoring with: ['filtertoolong']
# [2025-03-21 01:39:13,345 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2025-03-21 01:39:13,429 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2025-03-21 01:39:13,453 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2025-03-21 01:39:13,478 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2025-03-21 01:39:13,503 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2025-03-21 01:39:13,527 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# [2025-03-21 01:39:13,552 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# [2025-03-21 01:39:13,657 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# [2025-03-21 01:39:13,681 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# [2025-03-21 01:39:13,707 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# [2025-03-21 01:39:13,730 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# [2025-03-21 01:39:13,754 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# [2025-03-21 01:39:13,778 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# [2025-03-21 01:39:13,890 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 15
# [2025-03-21 01:39:13,915 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 16
# [2025-03-21 01:39:13,940 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 17
# [2025-03-21 01:39:13,965 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 18
# [2025-03-21 01:39:13,989 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 19
# [2025-03-21 01:39:14,013 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 20
# [2025-03-21 01:39:14,037 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 21
# [2025-03-21 01:39:14,061 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 22
# [2025-03-21 01:39:14,197 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 23
# [2025-03-21 01:39:14,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 24
# [2025-03-21 01:39:14,249 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 25
# [2025-03-21 01:39:14,274 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 26
# [2025-03-21 01:39:14,301 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 27
# [2025-03-21 01:39:14,327 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 28
# [2025-03-21 01:39:14,352 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 29
# [2025-03-21 01:39:14,377 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 30
# [2025-03-21 01:39:14,402 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 31
# [2025-03-21 01:39:14,426 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 32
# [2025-03-21 01:39:14,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 33
# [2025-03-21 01:39:14,608 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 34
# [2025-03-21 01:39:14,632 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 35
# [2025-03-21 01:39:14,657 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 36
# [2025-03-21 01:39:14,682 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 37
# [2025-03-21 01:39:14,706 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 38
# [2025-03-21 01:39:14,731 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 39
# [2025-03-21 01:39:14,755 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 40
# [2025-03-21 01:39:14,779 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 41
# [2025-03-21 01:39:14,804 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 42
# [2025-03-21 01:39:14,830 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 43
# [
INFO] Weighted corpora loaded so far:
# 			* corpus_1: 439
# [2025-03-21 01:49:46,689 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 440
# [2025-03-21 01:49:46,716 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 441
# [2025-03-21 01:49:46,741 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 442
# [2025-03-21 01:49:46,765 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 443
# [2025-03-21 01:49:46,792 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 444
# [2025-03-21 01:49:46,819 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 445
# [2025-03-21 01:49:46,846 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 446
# [2025-03-21 01:49:46,872 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 447
# [2025-03-21 01:49:46,898 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 448
# [2025-03-21 01:49:46,927 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 449
# [2025-03-21 01:49:46,954 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 450
# [2025-03-21 01:49:46,983 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 451
# [2025-03-21 01:49:47,013 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 452
# [2025-03-21 01:49:47,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 453
# [2025-03-21 01:49:47,080 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 454
# [2025-03-21 01:49:47,108 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 455
# [2025-03-21 01:49:47,139 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 456
# [2025-03-21 01:49:47,171 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 457
# [2025-03-21 01:49:47,202 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 458
# [2025-03-21 01:49:47,235 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 459
# [2025-03-21 01:49:47,272 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 460
# [2025-03-21 01:49:47,312 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 461
# [2025-03-21 01:49:47,345 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 462
# [2025-03-21 01:49:47,375 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 463
# [2025-03-21 01:49:47,405 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 464
# [2025-03-21 01:49:47,435 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 465
# [2025-03-21 01:49:47,465 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 466
# [2025-03-21 01:49:47,497 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 467
# [2025-03-21 01:49:47,525 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 468
# [2025-03-21 01:49:47,554 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 469
# [2025-03-21 01:49:47,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 470
# [2025-03-21 01:49:47,612 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 471
# [2025-03-21 01:49:47,642 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 472
# [2025-03-21 01:49:47,672 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 473
# [2025-03-21 01:49:47,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 474
# [2025-03-21 01:49:47,731 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 475
# [2025-03-21 01:49:47,759 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 476
# [2025-03-21 01:49:47,789 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 477
# [2025-03-21 01:49:47,818 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 478
# [2025-03-21 01:49:47,846 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 479
# [2025-03-21 01:49:47,874 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 480
# [2025-03-21 01:49:47,902 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 481
# [2025-03-21 01:49:47,930 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 482
# [2025-03-21 01:49:47,959 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 483
# [2025-03-21 01:49:50,294 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 484
# [2025-03-21 01:49:50,319 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 485
# [2025-03-21 01:49:50,346 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 486
# [2025-03-21 01:49:50,372 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 487
# [2025-03-21 01:49:50,397 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 488

# %% [markdown]
# ## Translate

# %%
# Translate the "subworded" source file of the test dataset
# Change the model name, if needed.
# !onmt_translate -model models/model.fren_step_3000.pt -src en-zh.zh-filtered.zh.subword.test -output en-zh.en-filtered.en.subword.translated -gpu 0 -min_length 1

# %%
# Check the first 5 lines of the translation file
# !head -n 5 en.translated

# %%
# If needed install/update sentencepiece
# !pip3 install --upgrade -q sentencepiece

# Desubword the translation file
# !python3 ./MT-Preparation/subwording/3-desubword.py ./target.model en.translated

# %%
# Desubword the target file (reference) of the test dataset
# Note: You might as well have split files *before* subwording during dataset preperation, 
# but sometimes datasets have tokeniztion issues, so this way you are sure the file is really untokenized.
# !python3 ./MT-Preparation/subwording/3-desubword.py ./target.model en-zh.en-filtered.en.subword.test

# %%
# Check the first 5 lines of the desubworded translation file
# !head -n 5 en.translated.desubword

# Check the first 5 lines of the desubworded reference
# !head -n 5 en-zh.en-filtered.en.subword.test.desubword

# %% [markdown]
# ## Evaluation

# %%
# Download the BLEU script
# !wget https://raw.githubusercontent.com/ymoslem/MT-Evaluation/main/BLEU/compute-bleu.py

# %%
# Install sacrebleu
# !pip3 install sacrebleu

# %%
# Evaluate the translation (without subwording)
# !python3 compute-bleu.py en-zh.en-filtered.en.subword.test.desubword en.translated.desubword
